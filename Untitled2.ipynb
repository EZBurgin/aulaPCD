# %% [markdown]
# <a href="https://colab.research.google.com/github/EZBurgin/aulaPCD/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 9
c = 7

media = (a+b+c)/3

print(f"O valor da média dos tres numeros é {media} ")
# Out:
# O valor da média dos tres numeros é 8.666666666666666

# %%
a = int(input("Digite o primeiro valor: "))
b = int(input("Digite o segundo valor: "))
c = int(input("Digite o terceiro valor: "))

media = (a+b+c)/3

print(f"O valor da média é {media}")
# Out:
# Digite o primeiro valor: 1
# Digite o segundo valor: 1
# Digite o terceiro valor: 1
# O valor da média é 1.0

# %%
# Terceira etapa pq esqueci de fazer dois commits

def media(a,b,c):
  m = (a+b+c)/3
  print(f"O valor da média é {m}")

media(9,9,9)
# Out:
# O valor da média é 9.0
